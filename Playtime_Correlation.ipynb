# %% [markdown]
# # Compute the correlation for the 2weeks playtime

# %%
# Import
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('RPG_Games_Data.csv', index_col=0).drop_duplicates()[['average_2weeks', 'name']]
print(df.shape)
df.head(2)
# Out:
# /home/jm/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (178656, 2)
#             average_2weeks                           name
# date
# 2017-11-01           190.0  Kingdoms of Amalur: Reckoning
# 2017-11-01           216.0   Disciples III: Reincarnation

# %%
df.columns
# Out:
# Index(['average_2weeks', 'name'], dtype='object')

# %%
df_corr = df.groupby([df.index, 'name']).mean().reset_index().pivot(index='date', columns='name', values='average_2weeks').fillna(0).corr()
df_corr.head()
# Out:
# name                                                 \
# name
#                                            1.000000
#  (Chinese PaladinSword and Fairy)         -0.153755
#  - Tales of Hongyuan                       0.067586
#  Chinese PaladinSword and Fairy 5 Prequel -0.040770
# (Chinese PaladinSword and Fairy 4)        -0.034002
#
# name                                        (Chinese PaladinSword and Fairy)  \
# name
#                                                                    -0.153755
#  (Chinese PaladinSword and Fairy)                                   1.000000
#  - Tales of Hongyuan                                                0.046200
#  Chinese PaladinSword and Fairy 5 Prequel                           0.081360
# (Chinese PaladinSword and Fairy 4)                                  0.226490
#
# name                                        - Tales of Hongyuan  \
# name
#                                                        0.067586
# ...

# %% [markdown]
# # Which games correlate?

# %%
game = ['The Elder Scrolls V: Skyrim', 'Stardew Valley', 'The Witcher 3: Wild Hunt'][0]
df_corr[game].sort_values(ascending=False).head(10)
# Out:
# name
# The Elder Scrolls V: Skyrim       1.000000
# Fasaria World: Browser MO         0.425836
# Angels of Fasaria: Version 2.0    0.375384
# Project RPG Remastered            0.371879
# Infinity Saga                     0.370499
# The Dwarf Run                     0.368237
# AoF World Online                  0.363265
# Jagged Alliance 2 - Wildfire      0.357408
# Wurm Unlimited                    0.351851
# MOBIUS FINAL FANTASY              0.319603
# Name: The Elder Scrolls V: Skyrim, dtype: float64
